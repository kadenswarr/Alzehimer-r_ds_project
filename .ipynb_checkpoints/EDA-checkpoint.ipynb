# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

question_key = pd.read_csv("data/question_key.csv")

# %%
new_data = pd.read_csv("data/flat_data.csv")

print(new_data.shape)
new_data.head(3)
# Out:
# (200, 67)
#    Year    State  Q01%  Q02%  Q03%  Q04%  Q08_Mean  Q09%  Q13%  Q14%  ...  \
# 0  2015  Alabama  18.2  10.6  12.4  90.7       6.1  58.4  36.2  93.7  ...
# 1  2015   Alaska  30.9  19.7   9.0  77.2       4.5  56.2  32.2  87.8  ...
# 2  2015  Arizona  30.0  17.8   9.6  84.9       5.4  62.4  29.2  90.9  ...
#
#    Total!!Population 25 years and over!!Associate's degree  \
# 0                                             266452
# 1                                              38113
# 2                                             382106
#
#    Total!!Population 25 years and over!!Bachelor's degree  \
# 0                                             504626
# 1                                              87869
# 2                                             788933
#
#    Total!!Population 25 years and over!!Graduate or professional degree  \
# 0                                             288250
# 1                                              51547
# ...

# %%
# Gives us an idea of how many nulls we have

print(new_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 67 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   Year                                                                                200 non-null    int64
#  1   State                                                                               200 non-null    object
#  2   Q01%                                                                                100 non-null    float64
#  3   Q02%                                                                                100 non-null    float64
#  4   Q03%                                                                                200 non-null    float64
# ...

# %%
state_abbr = [
"AL","AK","AZ","AR",
"CA","CO","CT","DE",
"FL","GA","HI","ID",
"IL","IN","IA","KS",
"KY","LA","ME","MD",
"MA","MI","MN","MS",
"MO","MT","NE","NV",
"NH","NJ","NM","NY",
"NC","ND","OH","OK",
"OR","PA","RI","SC",
"SD","TN","TX","UT",
"VT","VA","WA","WV",
"WI","WY"
]

sorted(state_abbr)

print(state_abbr[:3])
# Out:
# ['AL', 'AK', 'AZ']

# %%
states = new_data.groupby("State").mean()
states["abbr"] = state_abbr
states = states.sort_values("Mortality_Rate", ascending=False)

plt.figure(figsize=(30, 20))
sns.barplot(x=states.abbr, y=states.Mortality_Rate, data=states)

plt.show()
# prev = 0
# for i in range(25, 51, 25):
#     plt.figure(figsize=(25,10))
#     sns.barplot(x=states.abbr[prev:i], y="Mortality_Rate", data=states[prev:i])
#     plt.ylim(0, 100)
#     plt.show()
#     prev = i
# plt.figure(figsize=(20,10))
# sns.barplot(x=states.index[:15], y="Mortality_Rate", data=states[:15], capsize=50)
# plt.show()
# plt.figure(figsize=(20,10))
# plt.ylim(0, 50)
# sns.barplot(x=states.index[-15:], y="Mortality_Rate", data=states[-15:], capsize=50)
# plt.show()

# %%
# plots total sum of deaths by state
states = new_data.groupby("State").sum()
states["abbr"] = state_abbr
states = states.sort_values("Deaths", ascending=False)

plt.figure(figsize=(25, 10))
sns.barplot(x=states.abbr, y=states.Deaths, data=states)

plt.show()

# %%
df = new_data[['Year', 'State',
        'Percent!!Population 18 to 24 years!!Bachelor\'s degree or higher',
       'Percent!!Population 18 to 24 years!!High school graduate (includes equivalency)',
       'Percent!!Population 18 to 24 years!!Less than high school graduate',
       'Percent!!Population 18 to 24 years!!Some college or associate\'s degree',
        "Percent!!Population 25 years and over!!9th to 12th grade, no diploma",
       'Percent!!Population 25 years and over!!Associate\'s degree',
       'Percent!!Population 25 years and over!!Bachelor\'s degree',
       'Percent!!Population 25 years and over!!Graduate or professional degree',
       'Percent!!Population 25 years and over!!High school graduate (includes equivalency)',
       'Percent!!Population 25 years and over!!Less than 9th grade',
       'Percent!!Population 25 years and over!!Some college, no degree',
]].groupby("State").mean()

# %%
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 
# 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r',
# 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 
# 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu',
# 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r',
# 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd',
# 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 
# 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r',
# 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r',
# 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r',
# 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv',
# 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r',
# 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r',
# 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10',
# 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r',
# 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter',
# 'winter_r'

# %%
category_names  = ["No High School Diploma", "High School Grad", "Some Collge", "Bachelor's degree"]

results  = {
    "Less than high school graduate" : df["Percent!!Population 18 to 24 years!!Less than high school graduate"],
    "High school graduate" : df["Percent!!Population 18 to 24 years!!High school graduate (includes equivalency)"],
    "Some college or associate's degree" : df["Percent!!Population 18 to 24 years!!Some college or associate's degree"],
    "Bachelor's degree or higher" : df["Percent!!Population 18 to 24 years!!Bachelor's degree or higher"],
}

rest_results = {
    "Less than High School" : df['Percent!!Population 25 years and over!!Less than 9th grade'],
    "Some High School" : df["Percent!!Population 25 years and over!!9th to 12th grade, no diploma"],
    "High School Graduate" : df['Percent!!Population 25 years and over!!High school graduate (includes equivalency)'],
    "Some College" : df['Percent!!Population 25 years and over!!Some college, no degree'],
    "Associate's Degree" : df['Percent!!Population 25 years and over!!Associate\'s degree'],
    "Bachelor's Degree" : df['Percent!!Population 25 years and over!!Bachelor\'s degree'],
    "Gradute or Proffessional Degree" : df['Percent!!Population 25 years and over!!Graduate or professional degree']
}


def education(results, category_names, title):
    labels = list(df.index)
    data = np.array(list(results.values()))
    data_cum = np.cumsum(data, axis=0)
    
    
    fig, ax = plt.subplots(figsize=(20, 15))
    ax.set_title(title, loc="center")
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, 100)
    cat_colors = plt.get_cmap('BrBG')(
                np.linspace(0.15, 0.85 , data.shape[0]))

    for i, (colname, color) in enumerate(zip(category_names, cat_colors)):
        state = []
        state_cum = []
        for j in zip(range(data.shape[1])):
            state.append(data[i,j][0])
            state_cum.append(data_cum[i,j][0])
        widths = np.array(state)
        starts = np.array(state_cum) - widths
        xcenters = starts + widths / 2 

        ax.barh(labels, widths, left=starts, height=0.5,
               label=colname, color=color)


        for y, (x, c) in enumerate(zip(xcenters, widths)):
            ax.text(x, y, str(round(c, 2)), ha="center", va="center", color="black")

    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 0),
            loc="lower left")

    return fig, ax

education(results, category_names, "18 to 24 Years Old Education Percent")
plt.show()
education(rest_results, list(rest_results.keys()), "25 Years Old and Over Education Percent")
plt.show()

# %%
# graph trends by each state

new_data["abbr"] = (state_abbr * 4 )
plt.figure(figsize=(20,15))
plt.ylim(0,100)
plt.title("Mortality Rate by State Trends")
plt.xlabel("State")
sns.barplot(x= "abbr", y="Mortality_Rate",  data=new_data.sort_values("Mortality_Rate"))
plt.show()

# %%
new_data.columns
# Out:
# Index(['Year', 'State', 'Q01%', 'Q02%', 'Q03%', 'Q04%', 'Q08_Mean', 'Q09%',
#        'Q13%', 'Q14%', 'Q16%', 'Q17%', 'Q18%', 'Q19%', 'Q21%', 'Q22%', 'Q27%',
#        'Q32%', 'Q33%', 'Q35_Mean', 'Q36%', 'Q37%', 'Q38%', 'Q39%', 'Q40%',
#        'Q42%', 'Q43%', 'Q44%', 'Q45%', 'Q05%', 'Q07%', 'Q10%', 'Q11%', 'Q12%',
#        'Q15%', 'Q20%', 'Q34%', 'Q46%', 'Mortality_Rate', 'Deaths', 'Aqi',
#        'Percent!!Population 18 to 24 years!!Bachelor's degree or higher',
#        'Percent!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#        'Percent!!Population 18 to 24 years!!Less than high school graduate',
#        'Percent!!Population 18 to 24 years!!Some college or associate's degree',
#        'Percent!!Population 25 years and over!!9th to 12th grade, no diploma',
#        'Percent!!Population 25 years and over!!Associate's degree',
#        'Percent!!Population 25 years and over!!Bachelor's degree',
# ...

# %%
temp = new_data.groupby("Year").sum()

plt.xticks([2015, 2016, 2017, 2018])
sns.lineplot(x=temp.index, y="Deaths",  data=temp)
plt.show()

# %%
print(new_data["Mortality_Rate"].describe())
new_data.Mortality_Rate.hist()

plt.show()
# Out:
# count    200.000000
# mean      31.380000
# std        8.547103
# min       12.600000
# 25%       24.375000
# 50%       32.050000
# 75%       37.100000
# max       49.500000
# Name: Mortality_Rate, dtype: float64

# %%
print(new_data.Deaths.describe())
new_data.Deaths.hist()
plt.show()
# Out:
# count      200.000000
# mean      2348.040000
# std       2655.687758
# min         68.000000
# 25%        605.500000
# 50%       1718.000000
# 75%       3023.500000
# max      16627.000000
# Name: Deaths, dtype: float64

# %%
corr_matrix = new_data.corr()

pd.options.display.max_rows = 999
corr_matrix["Mortality_Rate"].sort_values(ascending=False)
# Out:
# Mortality_Rate                                                                        1.000000
# Percent!!Population 25 years and over!!Some college, no degree                        0.378716
# Q39%                                                                                  0.365005
# Q38%                                                                                  0.322532
# Percent!!Population 18 to 24 years!!Less than high school graduate                    0.317773
# Q27%                                                                                  0.279423
# Q13%                                                                                  0.271262
# Q08_Mean                                                                              0.265992
# Q45%                                                                                  0.254325
# Percent!!Population 25 years and over!!9th to 12th grade, no diploma                  0.248561
# ...

# %%
pd.options.display.max_colwidth = 200
question_key
# Out:
#    QuestionID  \
# 0         Q01
# 1         Q02
# 2         Q03
# 3         Q04
# 4         Q05
# 5         Q07
# 6         Q08
# 7         Q09
# 8         Q10
# 9         Q11
# 10        Q12
# 11        Q13
# 12        Q14
# 13        Q15
# 14        Q16
# 15        Q17
# 16        Q18
# 17        Q19
# 18        Q20
# 19        Q21
# 20        Q22
# 21        Q27
# 22        Q32
# 23        Q33
# 24        Q34
# 25        Q35
# 26        Q36
# 27        Q37
# 28        Q38
# 29        Q39
# 30        Q40
# 31        Q42
# 32        Q43
# 33        Q44
# 34        Q45
# 35        Q46
#
#                                                                                                                                                                      Question
# 0                                                                                                            Percentage of older adults who are eating 2 or more fruits daily
# ...
